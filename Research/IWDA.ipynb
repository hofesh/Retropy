# %%
# %run retropy.ipynb
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
swrd = get('SWRD.L')
swrd = swrd * get('GBPUSD@CUR', cache=True)

sppw = get('SPPW.DE')
sppw = sppw * get('EURUSD@CUR')

swrd_b = get('SWRD;LN@B')

vt = get('VT', mode='TR')
urth = get('URTH')
acwi = get('ACWI')

show(urth, swrd, sppw, trim=dt(2019, 3, 3), align='rel')
# Out:
# <div id="9440e4b4-16d0-47b4-a9d1-ab670998c539" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("9440e4b4-16d0-47b4-a9d1-ab670998c539", [{"connectgaps": false, "mode": "lines", "name": "URTH TR", "text": "URTH TR", "textposition": "middle right", "x": ["2019-03-03", "2019-03-04", "2019-03-05", "2019-03-06", "2019-03-07", "2019-03-08", "2019-03-09", "2019-03-10", "2019-03-11", "2019-03-12", "2019-03-13", "2019-03-14", "2019-03-15", "2019-03-16", "2019-03-17", "2019-03-18", "2019-03-19", "2019-03-20", "2019-03-21", "2019-03-22", "2019-03-23", "2019-03-24", "2019-03-25", "2019-03-26", "2019-03-27", "2019-03-28", "2019-03-29", "2019-03-30", "2019-03-31", "2019-04-01", "2019-04-02", "2019-04-03", "2019-04-04", "2019-04-05", "2019-04-06", "2019-04-07", "2019-04-08", "2019-04-09", "2019-04-10", "2019-04-11"
# ...

# %%
r = (urth / vt).dropna()
show(r, lr(r), ta=False)
cagr(r), cagr(lr(r))
# Out:
# <div id="e87f1d5f-49dd-4c42-aaf2-54243b48127f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e87f1d5f-49dd-4c42-aaf2-54243b48127f", [{"connectgaps": false, "mode": "lines", "name": "URTH TR / VT TR", "text": "URTH TR / VT TR", "textposition": "middle right", "x": ["2012-01-12", "2012-01-13", "2012-01-14", "2012-01-15", "2012-01-16", "2012-01-17", "2012-01-18", "2012-01-19", "2012-01-20", "2012-01-21", "2012-01-22", "2012-01-23", "2012-01-24", "2012-01-25", "2012-01-26", "2012-01-27", "2012-01-28", "2012-01-29", "2012-01-30", "2012-01-31", "2012-02-01", "2012-02-02", "2012-02-03", "2012-02-04", "2012-02-05", "2012-02-06", "2012-02-07", "2012-02-08", "2012-02-09", "2012-02-10", "2012-02-11", "2012-02-12", "2012-02-13", "2012-02-14", "2012-02-15", "2012-02-16", "2012-02-17", "2012-02-18", "2012-02-1
# ...
