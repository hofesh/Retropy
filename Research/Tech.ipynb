# %%
# %run retropy.ipynb
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# ARKW / FDN
# TSLA / SPY
# FB / FDN
# BABA / MCHI
# ZUO / SPY

#MCHI = get('MCHI', cache=False)

t = BABA
show_min_max_bands(t, 365*1.5, elr_fit=True)

r = t / MCHI
show_min_max_bands(r, 365*1.5)
# Out:
# Fetching MCHI from AV .. DONE
# <div id="963b9aba-663f-4861-ad2a-b56c204c17c2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '963b9aba-663f-4861-ad2a-b56c204c17c2',
# ...
